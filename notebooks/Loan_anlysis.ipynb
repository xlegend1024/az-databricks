# %% [markdown]
# # Loan data Analysis
#
# ## about the data
#
# This example uses simulated data at the individual level to analyze loan defaults. Data has been collected every year for 10 years on mortgage holders, stored in a comma delimited data set for each year. The data contains 5 variables:
#
# * default – a 0/1 binary variable indicating whether or not the mortgage holder defaulted on the loan
# * creditScore – a credit rating
# * yearsEmploy – the number of years the mortgage holder has been employed at their current job
# * ccDebt – the amount of credit card debt
# * houseAge – the age (in years) of the house
# * year – the year the data was collected

# %% [markdown]
# ## 1. Load Data

# %% [markdown]
# ## 1.1. Mount cloud storage to Databricks

# %%
# # Create folder in Databricks
# # dbutils.fs.mkdirs("/mnt/umpqua")

# # Option 1. 
# # Mount Azure Data Lake Gen1 to Databricks
# configs = {"dfs.adls.oauth2.access.token.provider.type": "ClientCredential",
#            "dfs.adls.oauth2.client.id": "<your-service-client-id>",
#            "dfs.adls.oauth2.credential": "<your-service-credentials>",
#            "dfs.adls.oauth2.refresh.url": "https://login.microsoftonline.com/<your-directory-id>/oauth2/token"}
# dbutils.fs.mount(
#   source = "adl://<your-data-lake-store-account-name>.azuredatalakestore.net/<your-directory-name>",
#   mount_point = "/mnt/umpqua",
#   extra_configs = configs)

# # Python 
dbutils.fs.mount(
  source = "wasbs://mortdefault@mtcsdataai.blob.core.windows.net",
  mount_point = "/mnt/umpqua",
  extra_configs = {"fs.azure.account.key.mtcsdataai.blob.core.windows.net":"d5XhBqQziobWFmcBhgFRzxP7PZZLMqqI0f9v5cCwG2F+Yemk4Z8rt75scnxdEt3GmvG84KEOeg5auZGzDE+KVw=="})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>True
# </div>

# %%
dbutils.fs.ls("/mnt/umpqua")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>
# [FileInfo(path=&apos;dbfs:/mnt/umpqua/mortDefault2000.csv&apos;, name=&apos;mortDefault2000.csv&apos;, size=21893223),
#  FileInfo(path=&apos;dbfs:/mnt/umpqua/mortDefault2001.csv&apos;, name=&apos;mortDefault2001.csv&apos;, size=21892195),
#  FileInfo(path=&apos;dbfs:/mnt/umpqua/mortDefault2002.csv&apos;, name=&apos;mortDefault2002.csv&apos;, size=21892645),
#  FileInfo(path=&apos;dbfs:/mnt/umpqua/mortDefault2003.csv&apos;, name=&apos;mortDefault2003.csv&apos;, size=21893232),
#  FileInfo(path=&apos;dbfs:/mnt/umpqua/mortDefault2004.csv&apos;, name=&apos;mortDefault2004.csv&apos;, size=21892662),
#  FileInfo(path=&apos;dbfs:/mnt/umpqua/mortDefault2005.csv&apos;, name=&apos;mortDefault2005.csv&apos;, size=21893168),
#  FileInfo(path=&apos;dbfs:/mnt/umpqua/mortDefault2006.csv&apos;, name=&apos;mortDefault2006.csv&apos;, size=21892837),
#  FileInfo(path=&apos;dbfs:/mnt/umpqua/mortDefault2007.csv&apos;, name=&apos;mortDefault2007.csv&apos;, size=21893845),
#  FileInfo(path=&apos;dbfs:/mnt/umpqua/mortDefault2008.csv&apos;, name=&apos;mortDefault2008.csv&apos;, size=21893146),
#  FileInfo(path=&apos;dbfs:/mnt/umpqua/mortDefault2009.csv&apos;, name=&apos;mortDefault2009.csv&apos;, size=21892789)]
# </div>

# %% [markdown]
# ## 1.2. Load data into a Table

# %%
# %sql

DROP TABLE IF EXISTS tblLoan;

CREATE TABLE tblloan (creditScore INT, houseAge INT, yearsEmploy INT, ccDebt INT, year INT, default INT)
  USING csv
  OPTIONS(path "/mnt/umpqua/", header "true");
  
SELECT count(1) FROM tblloan
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>10000000</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM tblloan limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>creditScore</th><th>houseAge</th><th>yearsEmploy</th><th>ccDebt</th><th>year</th><th>default</th></tr></thead><tbody><tr><td>710</td><td>22</td><td>6</td><td>5816</td><td>2007</td><td>0</td></tr><tr><td>684</td><td>25</td><td>3</td><td>4569</td><td>2007</td><td>0</td></tr><tr><td>719</td><td>23</td><td>8</td><td>4971</td><td>2007</td><td>0</td></tr><tr><td>715</td><td>25</td><td>7</td><td>7885</td><td>2007</td><td>0</td></tr><tr><td>592</td><td>14</td><td>5</td><td>3388</td><td>2007</td><td>0</td></tr><tr><td>718</td><td>17</td><td>9</td><td>5950</td><td>2007</td><td>0</td></tr><tr><td>735</td><td>15</td><td>6</td><td>6569</td><td>2007</td><td>0</td></tr><tr><td>764</td><td>22</td><td>2</td><td>7220</td><td>2007</td><td>0</td></tr><tr><td>709</td><td>1</td><td>4</td><td>4248</td><td>2007</td><td>0</td></tr><tr><td>679</td><td>27</td><td>9</td><td>4990</td><td>2007</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ## 2. Understand Data

# %% [markdown]
# ## 2.1. Cache data

# %%
# %sql
CACHE TABLE tblLoan
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED tblloan
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>creditScore</td><td>int</td><td>null</td></tr><tr><td>houseAge</td><td>int</td><td>null</td></tr><tr><td>yuearsEmploy</td><td>int</td><td>null</td></tr><tr><td>ccDebt</td><td>int</td><td>null</td></tr><tr><td>year</td><td>int</td><td>null</td></tr><tr><td>default</td><td>int</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>tblloan</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Tue Aug 07 17:32:49 UTC 2018</td><td></td></tr><tr><td>Last Access</td><td>Thu Jan 01 00:00:00 UTC 1970</td><td></td></tr><tr><td>Created By</td><td>Spark 2.3.0</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Provider</td><td>csv</td><td></td></tr><tr><td>Table Properties</td><td>[transient_lastDdlTime=1533663169]</td><td></td></tr><tr><td>Location</td><td>dbfs:/mnt/umpqua</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.mapred.SequenceFileInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.HiveSequenceFileOutputFormat</td><td></td></tr><tr><td>Storage Properties</td><td>[header=true, serialization.format=1]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# ## 2.2. Analyze the table columns

# %%
# %sql
ANALYZE TABLE tblLoan COMPUTE STATISTICS FOR COLUMNS creditScore, houseAge, yearsEmploy, ccDebt, year, default
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
--DESCRIBE EXTENDED tblloan creditScore;
DESCRIBE EXTENDED tblloan houseAge;
--DESCRIBE EXTENDED tblloan yearsEmploy;
--DESCRIBE EXTENDED tblloan ccDebt;
--DESCRIBE EXTENDED tblloan year;
--DESCRIBE EXTENDED tblloan default;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>info_name</th><th>info_value</th></tr></thead><tbody><tr><td>col_name</td><td>houseAge</td></tr><tr><td>data_type</td><td>int</td></tr><tr><td>comment</td><td>NULL</td></tr><tr><td>min</td><td>0</td></tr><tr><td>max</td><td>40</td></tr><tr><td>num_nulls</td><td>0</td></tr><tr><td>distinct_count</td><td>42</td></tr><tr><td>avg_col_len</td><td>4</td></tr><tr><td>max_col_len</td><td>4</td></tr><tr><td>histogram</td><td>NULL</td></tr></tbody></table></div>

# %% [markdown]
# ## 2.3. Get insights

# %%
# %sql
SELECT year, avg(yearsEmploy), avg(ccDebt), avg(creditScore), sum(default)
FROM tblLoan
GROUP BY year
ORDER BY year
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>avg(yearsEmploy)</th><th>avg(ccDebt)</th><th>avg(creditScore)</th><th>sum(default)</th></tr></thead><tbody><tr><td>2000</td><td>5.004967</td><td>5005.090791</td><td>700.010831</td><td>1031</td></tr><tr><td>2001</td><td>5.005778</td><td>5000.986526</td><td>700.012431</td><td>3133</td></tr><tr><td>2002</td><td>5.005144</td><td>5005.441205</td><td>699.995307</td><td>1182</td></tr><tr><td>2003</td><td>5.003071</td><td>5005.258709</td><td>700.085155</td><td>897</td></tr><tr><td>2004</td><td>5.003776</td><td>5002.812617</td><td>699.993788</td><td>533</td></tr><tr><td>2005</td><td>5.002872</td><td>5003.873686</td><td>700.097133</td><td>467</td></tr><tr><td>2006</td><td>5.006105</td><td>5003.031694</td><td>700.039365</td><td>700</td></tr><tr><td>2007</td><td>5.001984</td><td>5005.374889</td><td>700.092305</td><td>2060</td></tr><tr><td>2008</td><td>5.006477</td><td>5000.503625</td><td>700.092404</td><td>14811</td></tr><tr><td>2009</td><td>5.002597</td><td>5004.308067</td><td>699.963756</td><td>24741</td></tr></tbody></table></div>

# %%
# %sql
SELECT yearsEmploy, avg(ccDebt), avg(creditScore), avg(houseAge),sum(default)
FROM tblLoan
GROUP BY yearsEmploy
ORDER BY yearsEmploy
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>yearsEmploy</th><th>avg(ccDebt)</th><th>avg(creditScore)</th><th>avg(houseAge)</th><th>sum(default)</th></tr></thead><tbody><tr><td>0</td><td>5001.741785568692</td><td>700.1098736241337</td><td>19.986139421117</td><td>1480</td></tr><tr><td>1</td><td>5006.937039941861</td><td>699.8742741604726</td><td>19.996290753146205</td><td>2844</td></tr><tr><td>2</td><td>5004.159099861672</td><td>700.1219574756552</td><td>20.009098182195718</td><td>5464</td></tr><tr><td>3</td><td>5003.195591532168</td><td>699.9781222855536</td><td>19.994514439820982</td><td>8267</td></tr><tr><td>4</td><td>5004.5164944867465</td><td>700.0588191133751</td><td>19.99529162848565</td><td>9780</td></tr><tr><td>5</td><td>5003.048032166576</td><td>700.0356102465652</td><td>20.003168257883434</td><td>9080</td></tr><tr><td>6</td><td>5002.929065771634</td><td>700.0388166273032</td><td>20.005001977698875
td><td>16.0</td><td>0</td></tr><tr><td>0</td><td>533</td><td>4066.6666666666665</td><td>11.333333333333334</td><td>0</td></tr><tr><td>0</td><td>534</td><td>4292.333333333333</td><td>21.666666666666668</td><td>1</td></tr><tr><td>0</td><td>535</td><td>4065.0</td><td>18.0</td><td>0</td></tr><tr><td>0</td><td>536</td><td>6047.0</td><td>24.0</td><td>1</td></tr><tr><td>0</td><td>537</td><td>4598.0</td><td>24.5</td><td>0</td></tr><tr><td>0</td><td>538</td><td>4931.75</td><td>22.833333333333332</td><td>0</td></tr><tr><td>0</td><td>539</td><td>5028.833333333333</td><td>19.5</td><td>0</td></tr><tr><td>0</td><td>540</td><td>4701.166666666667</td><td>23.833333333333332</td><td>0</td></tr><tr><td>0</td><td>541</td><td>5433.142857142857</td><td>24.428571428571427</td><td>1</td></tr><tr><td>0</td><td>542</td><td>5688.333333333333</td><td>21.444444444444443</td><td>1</td></tr><tr><td>0</td><td>543</td><td>4692.375</td><td>18.0</td><td>1</td></tr><tr><td>0</td><td>544</td><td>5526.363636363636</td><td>20.272727272727273</td><td>0</td></tr><tr><td>0</td><td>545</td><td>4900.909090909091</td><td>20.454545454545453</td><td>0</td></tr><tr><td>0</td><td>546</td><td>4999.4</td><td>19.2</td><td>1</td></tr><tr><td>0</td><td>547</td><td>4905.64705882353</td><td>19.647058823529413</td><td>0</td></tr><tr><td>0</td><td>548</td><td>6664.333333333333</td><td>19.0</td><td>0</td></tr><tr><td>0</td><td>549</td><td>5602.357142857143</td><td>21.785714285714285</td><td>0</td></tr><tr><td>0</td><td>550</td><td>4629.846153846154</td><td>23.153846153846153</td><td>0</td></tr><tr><td>0</ ...

# %% [markdown]
# ## 2.4. Get insights using PowerBI Desktop

# %% [markdown]
# #### Data Visualization with PowerBI
#
# __Connect from PowerBI Desktop__
#
# * https://westus2.azuredatabricks.net:443/sql/protocolv1/o/1936248382440274/0727-170559-robin360
# * dapiaaaa4c70e641a81a9ccff772815d23f5

# %% [markdown]
# ## 3. Save data for Machine Learning
#
# __Save result to Blob for Azure Machine Learning Studio project__

# %%
# %python
import pandas as pd
# Remove the file if it exists
dbutils.fs.rm("/mnt/umpqua-amlstudio/loan", True)
# dbutils.fs.mkdirs("/mnt/umpqua-amlstudio")

# dbutils.fs.mount(
#   source = "wasbs://mortdefaultresult@mtcsdataai.blob.core.windows.net",
#   mount_point = "/mnt/umpqua-amlstudio",
#   extra_configs = {"fs.azure.account.key.mtcsdataai.blob.core.windows.net":"d5XhBqQziobWFmcBhgFRzxP7PZZLMqqI0f9v5cCwG2F+Yemk4Z8rt75scnxdEt3GmvG84KEOeg5auZGzDE+KVw=="})

df = spark.sql("select * from tblloan")
df.coalesce(1).write.options(header='true').format("com.databricks.spark.csv").save("/mnt/umpqua-amlstudio/loan")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls("/mnt/umpqua-amlstudio/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">25</span><span class="ansired">]: </span>[FileInfo(path=&apos;dbfs:/mnt/umpqua-amlstudio/loan/&apos;, name=&apos;loan/&apos;, size=0)]
# </div>

# %% [markdown]
# # End of notebook 2018. 8. 8.
